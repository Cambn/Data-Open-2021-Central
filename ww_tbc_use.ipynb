# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json
import plotly.express as px
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
with open('config/EDA.json') as fh:
    configs = json.load(fh)
    TBC_WW_PATH, EDA_VIZ_PATH, PRODUCTION_ = configs['TBC_WW_PATH'], configs['EDA_VIZ_PATH']

# %%
tbc_ww = pd.read_csv(TBC_WW_PATH)
us_tbc_usage = tbc_ww.copy().loc[tbc_ww['SpatialDimValueCode']=='USA'].iloc[:, 4:]
us_tbc_usage.shape
# Out:
# (27, 3)

# %%
us_tbc_usage
# Out:
#       Year      Gender  Value
# 123   2018      Female   19.3
# 207   2018  Both sexes   25.1
# 282   2018        Male   30.9
# 571   2017      Female   19.6
# 655   2017  Both sexes   25.3
# 731   2017        Male   31.0
# 1017  2016      Female   19.9
# 1103  2016  Both sexes   25.7
# 1179  2016        Male   31.5
# 1472  2015      Female   20.2
# 1551  2015  Both sexes   26.0
# 1623  2015        Male   31.9
# 1918  2014      Female   20.6
# 1997  2014  Both sexes   26.4
# 2070  2014        Male   32.3
# 2361  2013      Female   20.8
# 2440  2013  Both sexes   26.8
# 2516  2013        Male   32.7
# 2809  2010      Female   21.8
# 2892  2010  Both sexes   27.9
# 2962  2010        Male   33.9
# 3263  2005      Female   23.8
# 3336  2005  Both sexes   30.0
# 3407  2005        Male   36.1
# 3707  2000      Female   25.9
# 3776  2000  Both sexes   32.3
# 3842  2000        Male   38.6

# %%
sns.linealue', hue='Gender')plot(data=us_tbc_usage, x='Year', y='V
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>
